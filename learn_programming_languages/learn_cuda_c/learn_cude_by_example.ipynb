# %% [markdown]
# <a href="https://colab.research.google.com/github/eliaschikwanda/learn-code/blob/main/learn_programming_languages/learn_cuda_c/learn_cude_by_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
